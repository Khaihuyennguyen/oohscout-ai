# %% [markdown]
# # F5 Code-Along — Retype from Memory
#
# Same rules as F1/F2/F4 code-alongs.
#
# 1. Read each prompt.
# 2. Type the code in the blank cell below.
# 3. Run it.
# 4. Peek at `03_oohscout_adaptation.ipynb` only if truly stuck — and retype, don't paste.
#
# **Success:** side-by-side plot renders, clipped IH-35 is fewer segments than full.

# %% [markdown]
# ## 1. Imports
#
# **Type the imports F5 needs.** Hint: same core set as F2 plus `time.perf_counter` and `shapely.geometry.box`.

# %%
# Your code here

# %% [markdown]
# ## 2. Load F1 + F2
#
# **Call the two `load_or_build_...` functions and time them together.** Print the county area, IH-35 length, and elapsed seconds.

# %%
# Your code here

# %% [markdown]
# ## 3. Define + project the Waco bbox
#
# **Type `WACO_URBAN_BBOX = (-97.20, 31.48, -97.05, 31.62)` and convert it to the metric CRS.**
#
# **Trap:** what happens if you pass the raw tuple to Shapely without wrapping in `box()` first? What error do you get?

# %%
# Your code here

# %% [markdown]
# ## 4. Clip the corridor
#
# **Use `.intersects(bbox_metric)` to keep only IH-35 segments that touch the bbox.** Print `len(clipped)` and total km.
#
# **Question to answer in a comment:** why NOT use `.within(bbox_metric)`?

# %%
# Your code here

# %% [markdown]
# ## 5. Side-by-side plot
#
# **Create two subplots.** Left = full county + full IH-35. Right = bbox + clipped IH-35. Save PNG before `plt.show()`.

# %%
# Your code here

# %% [markdown]
# ## Reflection
#
# 1. Roughly what percent of the full county does the bbox cover?
# 2. If you extended the bbox to also cover Elm Mott and West, what would change (numerically)?
# 3. Why is `intersects` the safe default for lines, and when would `within` be correct?
# 4. Where should the `WACO_URBAN_BBOX` constant live — inside the F5 module, inside `study_area.py`, or somewhere else? Why?
