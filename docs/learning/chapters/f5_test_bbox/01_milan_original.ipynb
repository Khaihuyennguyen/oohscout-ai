# %% [markdown]
# # F5 — Milan Original (Pointer)
#
# F5 uses the **same `TEST_BBOX` pattern from UA Advanced Chapter 1** that you already retyped in F1's [01_milan_original.ipynb](../ua_advanced_ch01_setup/01_milan_original.ipynb) (Section 1.4 — Fast Test Bounding Box).
#
# **Milan's version (Manhattan Midtown):**
# ```python
# TEST_BBOX = (-73.9890, 40.7520, -73.9800, 40.7580)  # (minx, miny, maxx, maxy)
# box_wgs84 = gpd.GeoSeries([box(*TEST_BBOX)], crs=CRS_GEOGRAPHIC)
# box_metric = box_wgs84.to_crs(epsg=CRS_METRIC)
# test_poly = box_metric.iloc[0]
#
# buildings_test = buildings[buildings.intersects(test_poly)].reset_index(drop=True)
# ```
#
# **F5's version (Waco urban core):** replace the Manhattan bbox with a Waco bbox and apply the same `intersects` filter to any GeoDataFrame we want to shrink.
#
# **Nothing new to retype here.** Skip to [03_oohscout_adaptation.ipynb](03_oohscout_adaptation.ipynb).
