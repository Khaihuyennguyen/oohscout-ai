# %% [markdown]
# # F4 — Milan Original (Pointer)
#
# F4 is **not** a Milan course chapter. It comes from two places:
#
# 1. **`CLAUDE.md` project rule:** *"Every dataset in production code must carry license metadata: source, commercial_use_allowed, redistribution_allowed."*
# 2. **Milan UA Advanced Ch 4 discipline:** Milan documents the source of every dataset he uses (NYC Parks, Manhattan census tracts) in a markdown cell above the download call. F4 formalizes that discipline into a YAML sidecar so machines can verify it.
#
# **Nothing to retype from Milan for F4.** Skip straight to [03_oohscout_adaptation.ipynb](03_oohscout_adaptation.ipynb).
